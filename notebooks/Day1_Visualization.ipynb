# %% [markdown]
# # Table of Contents
#  <p><div class="lev1 toc-item"><a href="#Read-Tutorial-on-matplotlib" data-toc-modified-id="Read-Tutorial-on-matplotlib-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Read Tutorial on matplotlib</a></div><div class="lev1 toc-item"><a href="#Plot-the-Normal-Distribution" data-toc-modified-id="Plot-the-Normal-Distribution-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Plot the Normal Distribution</a></div><div class="lev2 toc-item"><a href="#Now-as-Boxplots" data-toc-modified-id="Now-as-Boxplots-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Now as Boxplots</a></div><div class="lev2 toc-item"><a href="#Finally-let's-do-some-Histograms" data-toc-modified-id="Finally-let's-do-some-Histograms-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Finally let's do some Histograms</a></div>

# %%
# %matplotlib inline

# %% [markdown]
# # Read Tutorial on matplotlib
# [matplotlib](http://matplotlib.org/) is a 2D plotting library for python which can also be used to create inline plots in jupyter notebooks. To get familiar with the basic plotting concepts, walk through [this](http://www.labri.fr/perso/nrougier/teaching/matplotlib/) tutorial and create all the plots therein. Note that it's easier to learn and remember the commands if you don't just copy & paste, but retype the examples!

# %% [markdown]
# ## Using defaults

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
X = np.linspace(-np.pi, np.pi, 256, endpoint = False)
C = np.cos(X)
S = np.sin(X)
plt.plot(X,C)
plt.plot(X,S)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# ## Instantiating defaults

# %%
# Create a new figure of size 8x6 points 
plt.figure(figsize=(8,6), dpi=80)

# Create  a new subplot from a grid of 1x1
plt.subplot(111)

X = np.linspace(-np.pi, np.pi, 256, endpoint=True)
C,S = np.cos(X), np.sin(X)

# Plot cosine using blue color with a continuous line of width 1 
plt.plot(X, C, color="blue", linewidth=1.0, linestyle="-")

# Plot sine using green color with a continuous line of width 1
plt.plot(X, S, color="green", linewidth=1.0, linestyle="-")

# Set x limits
plt.xlim(-4.0, 4.0)

# Set x ticks
plt.xticks(np.linspace(-4,4,9,endpoint=True))

# Set y limits 
plt.ylim(-1.0,1.0)

# Set y ticks
plt.yticks(np.linspace(-1,1,5,endpoint=True))

# Save figure using 72 dots per inch 
plt.savefig("figures/day1_first_plot.png",dpi=72)

# Show result on screen
plt.show()

# %% [markdown]
# ## Changing colors and line widths

# %% [markdown]
# We want to have the cosine in blue and the sine in red and a slightly thicker line for both of them. We'll also slighty alter the figure size to make it more horizontal.

# %%
plt.figure(figsize=(10,6), dpi=80)
plt.plot(X, C, color="blue", linewidth=2.5, linestyle="-")
plt.plot(X, S, color="red", linewidth=2.5, linestyle="-")

# %% [markdown]
# ## Setting limits

# %% [markdown]
# Current limits of the figure are a bit too tight and we want to make some space in order to clearly see all data points.

# %%
plt.xlim(X.min()*1.1, X.max()*1.1)
plt.ylim(C.min()*1.1, X.max()*1.1)

# plot 
plt.plot(X, C, color="blue", linewidth=2.5, linestyle="-")
plt.plot(X, S, color="red", linewidth=2.5, linestyle="-")

# %% [markdown]
# ## Setting ticks

# %% [markdown]
# Current ticks are not ideal because they do not show the interesting values (+/-$\pi$,+/-$\pi$/2) for sine and cosine.

# %%
plt.xticks( [-np.pi, np.pi/2, 0, np.pi/2, np.pi])
plt.yticks([-1, 0, +1])

plt.plot(X, C, color="blue", linewidth=2.5, linestyle="-")
plt.plot(X, S, color="red", linewidth=2.5, linestyle="-")

# %% [markdown]
# ## Setting tick labels

# %% [markdown]
# When we set tick values, we can also provide a corresponding label in the second argument list.

# %%
plt.xticks([-np.pi, -np.pi/2, 0, np.pi/2, np.pi],
          [r'$-\pi$', r'$-\pi/2$', r'$0$', r'$+pi/2$', r'$+\pi/2$'])

plt.yticks([-1, 0, +1],
          [r'$-1$', r'$0$', r'$+1$'])

plt.plot(X, C, color="blue", linewidth=2.5, linestyle="-")
plt.plot(X, S, color="red", linewidth=2.5, linestyle="-")

# %% [markdown]
# ## Moving spines

# %% [markdown]
# Spines are the lines connecting the axis tick marks and noting the boundaries of the data area. We'll change that sine we want to have them in the middle. Since there are four of them (top/bottom/left/right), we'll discard the top and right by setting their color to none and we'll move the bottom and the left ones to coordinate 0 in data space coordinates.

# %%
ax = plt.gca()
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data',0))
ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data',0))

plt.plot(X, C, color="blue", linewidth=2.5, linestyle="-")
plt.plot(X, S, color="red", linewidth=2.5, linestyle="-")

# %% [markdown]
# ## Adding a legend

# %% [markdown]
# Let's add a legend in the upper left corner.

# %%
plt.plot(X, C, color="blue", linewidth=2.5, linestyle="-", label="cosine")
plt.plot(X, S, color="red", linewidth=2.5, linestyle="-", label="sine")

plt.legend(loc='upper left', frameon=False)

# %% [markdown]
# ## Annotate some points

# %% [markdown]
# Let's annotate some interesting points using the annotate command.

# %%
plt.plot(X, C, color="blue", linewidth=2.5, linestyle="-", label="cosine")
plt.plot(X, S, color="red", linewidth=2.5, linestyle="-", label="sine")

plt.legend(loc='upper left', frameon=False)

t = 2*np.pi/3
plt.plot([t,t],[0,np.cos(t)], color='blue', linewidth=1.5, linestyle="--")
plt.scatter([t,],[np.cos(t),], 50, color='blue')

plt.annotate(r'$\sin(\frac{2\pi}{3})=\frac{\sqrt{3}}{2}$',
            xy=(t, np.sin(t)), xycoords='data',
            xytext=(+10, +30), textcoords='offset points', fontsize=16,
            arrowprops=dict(arrowstyle="->", connectionstyle="arc3,rad=.2"))

plt.plot([t,t],[0,np.sin(t)], color='red', linewidth=1.5, linestyle="--")
plt.scatter([t,],[np.sin(t),], 50, color='red')

plt.annotate(r'$\cos(\frac{2\pi}{3})=\frac{1}{2}$',
            xy=(t, np.cos(t)), xycoords='data',
            xytext=(-90, -50), textcoords='offset points', fontsize=16,
            arrowprops=dict(arrowstyle="->", connectionstyle="arc3,rad=.2"))

# %% [markdown]
# ## Devil is in the details

# %% [markdown]
# The tick labels are now hardly visible because of the blue and red lines.

# %%
# old stuff (required for plotting)
plt.plot(X, C, color="blue", linewidth=2.5, linestyle="-", label="cosine")
plt.plot(X, S, color="red", linewidth=2.5, linestyle="-", label="sine")

plt.legend(loc='upper left', frameon=False)

t = 2*np.pi/3
plt.plot([t,t],[0,np.cos(t)], color='blue', linewidth=1.5, linestyle="--")
plt.scatter([t,],[np.cos(t),], 50, color='blue')

plt.annotate(r'$\sin(\frac{2\pi}{3})=\frac{\sqrt{3}}{2}$',
            xy=(t, np.sin(t)), xycoords='data',
            xytext=(+10, +30), textcoords='offset points', fontsize=16,
            arrowprops=dict(arrowstyle="->", connectionstyle="arc3,rad=.2"))

plt.plot([t,t],[0,np.sin(t)], color='red', linewidth=1.5, linestyle="--")
plt.scatter([t,],[np.sin(t),], 50, color='red')

plt.annotate(r'$\cos(\frac{2\pi}{3})=\frac{1}{2}$',
            xy=(t, np.cos(t)), xycoords='data',
            xytext=(-90, -50), textcoords='offset points', fontsize=16,
            arrowprops=dict(arrowstyle="->", connectionstyle="arc3,rad=.2"))


# new stuff
for label in ax.get_xticklabels() + ax.get_yticklabels():
    label.set_fontsize(16)
    label.set_bbox(dict(facecolor='white', edgecolor='None', alpha=0.65))

# %% [markdown]
# # Plot the Normal Distribution
# Now you should be able to reproduce the following plot (taken from Wikipedia):
# <img src='https://upload.wikimedia.org/wikipedia/commons/thumb/7/74/Normal_Distribution_PDF.svg/720px-Normal_Distribution_PDF.svg.png'>

# %%
import matplotlib.mlab as mlab
import math

# %%
x = np.linspace(-5,5,100)

plt.figure(figsize=(11,6), dpi=80)

plt.xlim(x.min()*1.1, x.max()*1.1)
plt.ylim(-0.1*1.1, 1*1.1)


plt.plot(x,mlab.normpdf(x,0,math.sqrt(0.2)), color="blue", linewidth=2.5, label=r'$\mu=0$,    $\sigma^2=0.2$')
plt.plot(x,mlab.normpdf(x,0,math.sqrt(1.0)), color="red", linewidth=2.5, label=r'$\mu=0$,     $\sigma^2=1.0$')
plt.plot(x,mlab.normpdf(x,0,math.sqrt(5.0)), color="orange", linewidth=2.5, label=r'$\mu=0$,     $\sigma^2=5.0$')
plt.plot(x,mlab.normpdf(x,-2,math.sqrt(0.5)), color="green", linewidth=2.5, label=r'$\mu=-2$,  $\sigma^2=0.5$')

plt.grid(linestyle='-', linewidth=.15)
plt.xticks(np.linspace(-5,5,11))
plt.minorticks_on()

plt.tick_params(axis='both', which='major', length=20, width=0)
plt.tick_params(axis='both', which='minor', length=10, width=1)

plt.xlabel('$X$', fontsize=25)
plt.ylabel(r'$\varphi_{\mu,\sigma^2}(X)}$', fontsize=25)
plt.legend(loc='upper right', frameon=False)

# %% [markdown]
# ## Now as Boxplots
# Now have a look at [seaborn](https://stanford.edu/~mwaskom/software/seaborn/index.html) and use it to plot random 1000 samples of  these normal distributions as boxplots. You should get something similar as this:
# <img src="boxplot_solution.png"></img>

# %%
import seaborn as sns
import pandas as pd

# %%
distr1 = np.random.normal(0, math.sqrt(2), 1000)
distr2 = np.random.normal(0, math.sqrt(1), 1000)
distr3 = np.random.normal(0, math.sqrt(5), 1000)
distr4 = np.random.normal(-2, math.sqrt(0.5), 1000)

df = pd.DataFrame({ '0' : distr1,
                    '1' : distr2,
                    '2' : distr3,
                    '3' : distr4})

plt.ylim(10,-8)
sns.boxplot(data=df)

plt.grid(linestyle='-', linewidth=0)

# %% [markdown]
# ## Finally let's do some Histograms
# Now use the samples of the previous exercise and plot them as histograms (i) in sublots:
# <img src="histo_subplots.png"></img>
# and overlayed into one plot:
# <img src="histo_kde.png"></img>

# %%
plt.figure(figsize=(10,10))

#add_subplot(111)

plt.subplot(221)
plt.hist(distr1)
plt.title(r'$\mu=0,\sigma^2=0.2$')
xlim=(-2,1.5)
plt.grid(linestyle='-', linewidth=0)

plt.subplot(222)
plt.hist(distr2)
plt.title(r'$\mu=0,\sigma^2=1.0$')
plt.grid(linestyle='-', linewidth=0)

plt.subplot(223)
plt.hist(distr3)
plt.title(r'$\mu=0,\sigma^2=5.0$')
plt.grid(linestyle='-', linewidth=0)

plt.subplot(224)
plt.hist(distr4)
plt.title(r'$\mu=-2,\sigma^2=0.5$')
plt.grid(linestyle='-', linewidth=0)

#distr1 = np.random.normal(0, math.sqrt(0.2), 1000)
#distr2 = np.random.normal(0, math.sqrt(1), 1000)
#distr3 = np.random.normal(0, math.sqrt(5), 1000)
#distr4 = np.random.normal(-2, math.sqrt(0.5), 1000)

# %%
sns.distplot(distr1, color="blue", label=r'$\mu=0$, $\sigma^2=0.2$')
sns.distplot(distr2, color="red", label=r'$\mu=0$, $\sigma^2=1.0$')
sns.distplot(distr3, color="orange", label=r'$\mu=0$, $\sigma^2=5.0$')
sns.distplot(distr4, color="green", label=r'$\mu=-2$, $\sigma^2=0.5$')

#plt.plot(x,mlab.normpdf(x,0,math.sqrt(0.2)), color="blue", linewidth=2.5, label=r'$\mu=0$,    $\sigma^2=0.2$')
#plt.plot(x,mlab.normpdf(x,0,math.sqrt(1.0)), color="red", linewidth=2.5, label=r'$\mu=0$,     $\sigma^2=1.0$')
#plt.plot(x,mlab.normpdf(x,0,math.sqrt(5.0)), color="orange", linewidth=2.5, label=r'$\mu=0$,     $\sigma^2=5.0$')
#plt.plot(x,mlab.normpdf(x,-2,math.sqrt(0.5)), color="green", linewidth=2.5, label=r'$\mu=-2$,  $\sigma^2=0.5$')


plt.grid(linestyle='-', linewidth=0)
plt.legend(loc='upper right', frameon=False)
